# %% [markdown]
# # UNLP Machine Learning - TP1
# ---------------------------------------
# * **Autores:**
#     - Emiliano Bohorquez
#     - Brayan A. Condori Luque
# * **Objetivo:** Este notebook prepara los datos extraidos del [sitio web](https://ignaciomsarmiento.github.io/GEIH2018_sample/).
# ---------------------------------------
#
# **Fecha de Creación:** 2024-11-18
#
# **Fecha de Actualización:** 2024-11-24

# %%
# Importamos las librerias
import pandas as pd
pd.set_option('display.float_format', '{:.2f}'.format)

import os

# %%
# Definimos las rutas de los archivos
DATASET_RAW = "../stores/raw_geih_data.csv"
DATASET_CLEAN = "../stores/clean_geih_data.csv"

# %%
# 1. Abrimos la base de datos
df = pd.read_csv(DATASET_RAW, sep=",")
df
# Out:
#       directorio secuencia_p orden clase dominio mes estrato1 sex age p6050  \
# 0        4514331           1     2     1  BOGOTA   1        2   0  29     2
# 1        4514331           1     1     1  BOGOTA   1        2   1  36     1
# 2        4514332           1     4     1  BOGOTA   1        2   1   4     3
# 3        4514332           1     3     1  BOGOTA   1        2   1   7     3
# 4        4514332           1     1     1  BOGOTA   1        2   0  32     1
# ...          ...         ...   ...   ...     ...  ..      ...  ..  ..   ...
# 32181    4804454           1     2     1  BOGOTA  12        2   0  24     2
# 32182    4804455           1     1     1  BOGOTA  12        3   0  36     1
# 32183    4804455           1     2     1  BOGOTA  12        3   1  41     2
# 32184    4804455           1     3     1  BOGOTA  12        3   1   8     3
# 32185    4804455           1     4     1  BOGOTA  12        3   0   0     3
#
#        ... y_viaticos_m y_accidentes_m y_salarysec_m    y_inglab_m_ha  \
# 0      ...          NaN            NaN           NaN              NaN
# 1      ...          NaN            NaN           NaN     8404.3203125
# 2      ...          NaN            NaN           NaN              NaN
# 3      ...          NaN            NaN           NaN              NaN
# 4      ...          NaN            NaN           NaN              NaN
# ...    ...          ...            ...           ...              ...
# 32181  ...          NaN            NaN           NaN  3345.5556640625
# 32182  ...        5e+05            NaN           NaN  25958.333984375
# 32183  ...          NaN            NaN           NaN              NaN
# 32184  ...          NaN            NaN           NaN              NaN
# 32185  ...          NaN            NaN           NaN              NaN
#
#       y_ganancianeta_m y_ganancianetaagro_m y_gananciaindep_m  \
# 0                  NaN                  NaN               NaN
# 1                  NaN                  NaN               NaN
# 2                  NaN                  NaN               NaN
# 3                  NaN                  NaN               NaN
# 4                  NaN                  NaN               NaN
# ...                ...                  ...               ...
# 32181              NaN                  NaN               NaN
# 32182              NaN                  NaN               NaN
# 32183              NaN                  NaN               NaN
# 32184              NaN                  NaN               NaN
# 32185              NaN                  NaN               NaN
#
#       y_gananciaindep_m_hu     y_total_m     y_total_m_ha
# 0                      NaN           NaN              NaN
# 1                      NaN    1620833.25     8404.3203125
# 2                      NaN           NaN              NaN
# 3                      NaN           NaN              NaN
# 4                      NaN           NaN              NaN
# ...                    ...           ...              ...
# 32181                  NaN  1003666.6875  3345.5556640625
# 32182                  NaN       6675000  25958.333984375
# 32183                  NaN           NaN              NaN
# 32184                  NaN           NaN              NaN
# 32185                  NaN           NaN              NaN
#
# [32186 rows x 177 columns]

# %% [markdown]
# Segun las indicaciones de la consigna. Mantenemos las observaciones bajo los siguientes siguientes criterios:
# * Individuos con una edad igual o superior a los 18 años.
# * Evitar NAs que distorsionen los procedimientos.
# * Individuos que tienen ingresos laborales mayores a cero.

# %%
# 2. Limpiamos la base de datos

# Transformamos a variable númerica
df['age'] = pd.to_numeric(df['age'], errors='coerce').fillna(0).astype(int)

# Filtramos por edad
df_18 = df[df['age']>= 18]

# Filtramos por ingreso positivo
df_18 = df_18[df_18['y_salary_m_hu'] != 0]

# Transformo el tipo de variable. Comenzamos por una selección de las mismas
variables = ['estrato1','sex','age', 'formal','fweight','maxeduclevel','y_salary_m_hu', 'y_inglab_m',
            'p6585s1', 'p6585s2', 'p6585s3', 'p6585s4']

for v in variables:
    df_18[v] = df_18[v].astype(float)

# Reseteamos el índice
df_18.reset_index(drop=True, inplace=True)

# %%
# El dataset resultante queda de la siguiente manera
print(f"El dataset cuenta con un total de {df_18.shape[0]} observaciones")

df_18
# Out:
# El dataset cuenta con un total de 24568 observaciones
#       directorio secuencia_p orden clase dominio mes  estrato1  sex   age  \
# 0        4514331           1     2     1  BOGOTA   1      2.00 0.00 29.00
# 1        4514331           1     1     1  BOGOTA   1      2.00 1.00 36.00
# 2        4514332           1     1     1  BOGOTA   1      2.00 0.00 32.00
# 3        4514332           1     2     1  BOGOTA   1      2.00 1.00 35.00
# 4        4514333           1     4     1  BOGOTA   1      2.00 1.00 18.00
# ...          ...         ...   ...   ...     ...  ..       ...  ...   ...
# 24563    4804453           1     9     1  BOGOTA  12      3.00 1.00 23.00
# 24564    4804454           1     1     1  BOGOTA  12      2.00 1.00 27.00
# 24565    4804454           1     2     1  BOGOTA  12      2.00 0.00 24.00
# 24566    4804455           1     1     1  BOGOTA  12      3.00 0.00 36.00
# 24567    4804455           1     2     1  BOGOTA  12      3.00 1.00 41.00
#
#       p6050  ... y_viaticos_m y_accidentes_m y_salarysec_m    y_inglab_m_ha  \
# 0         2  ...          NaN            NaN           NaN              NaN
# 1         1  ...          NaN            NaN           NaN     8404.3203125
# 2         1  ...          NaN            NaN           NaN              NaN
# 3         2  ...          NaN            NaN           NaN              NaN
# 4         3  ...          NaN            NaN           NaN              NaN
# ...     ...  ...          ...            ...           ...              ...
# 24563     4  ...          NaN            NaN           NaN              NaN
# 24564     1  ...          NaN            NaN           NaN      4453.359375
# 24565     2  ...          NaN            NaN           NaN  3345.5556640625
# 24566     1  ...        5e+05            NaN           NaN  25958.333984375
# 24567     2  ...          NaN            NaN           NaN              NaN
#
#       y_ganancianeta_m y_ganancianetaagro_m y_gananciaindep_m  \
# 0                  NaN                  NaN               NaN
# 1                  NaN                  NaN               NaN
# 2                  NaN                  NaN               NaN
# 3                  NaN                  NaN               NaN
# 4                  NaN                  NaN               NaN
# ...                ...                  ...               ...
# 24563            2e+05                  NaN             2e+05
# 24564              NaN                  NaN               NaN
# 24565              NaN                  NaN               NaN
# 24566              NaN                  NaN               NaN
# 24567              NaN                  NaN               NaN
#
#       y_gananciaindep_m_hu     y_total_m     y_total_m_ha
# 0                      NaN           NaN              NaN
# 1                      NaN    1620833.25     8404.3203125
# 2                      NaN           NaN              NaN
# 3                      NaN           NaN              NaN
# 4                      NaN           NaN              NaN
# ...                    ...           ...              ...
# 24563      9333.3330078125         2e+05  9333.3330078125
# 24564                  NaN   916119.6875      4453.359375
# 24565                  NaN  1003666.6875  3345.5556640625
# 24566                  NaN       6675000  25958.333984375
# 24567                  NaN           NaN              NaN
#
# [24568 rows x 177 columns]

# %%
#3. Realizamos una selección de var

df_18 = df_18[['directorio', 'secuencia_p', 'orden', 'formal','estrato1', 'sex', 'age','fweight', 'maxeduclevel',
              'y_salary_m_hu','y_total_m', 'p6585s1', 'p6585s2', 'p6585s3', 'p6585s4']]

# Transformamos las variables subsidios en dicotómicas. Primero, quitamos los que respondieron no saber:
subsidios = ['p6585s1', 'p6585s2', 'p6585s3', 'p6585s4']
for s in subsidios:
    df_18 = df_18[df_18[s] != 9.0]

# Ahora reemplazamos los que responden que no por 0 y los que sí por 1:
for s in subsidios:
    df_18[s] = df_18[s].apply(lambda x: 1 if x == 1 else 0)
df_18

# Filtramos por aquellos que no respondieron su nivel educativo
df_18 = df_18[df_18['maxeduclevel'] != 0.0]


# Por último, eliminamos los NaN:

df_18.dropna(how="any", inplace=True)

# El dataset resultante queda de la siguiente manera
print(f"El dataset cuenta con un total de {df_18.shape[0]} observaciones")

df_18
# Out:
# El dataset cuenta con un total de 9844 observaciones
#       directorio secuencia_p orden  formal  estrato1  sex   age  fweight  \
# 1        4514331           1     1    1.00      2.00 1.00 36.00   255.00
# 6        4514333           1     1    1.00      2.00 1.00 51.00   194.00
# 9        4514334           1     1    1.00      2.00 1.00 45.00   243.00
# 11       4514335           1     1    0.00      2.00 1.00 61.00   230.00
# 16       4514338           1     2    1.00      2.00 0.00 35.00   342.00
# ...          ...         ...   ...     ...       ...  ...   ...      ...
# 24560    4804453           1     6    1.00      3.00 1.00 24.00   233.00
# 24562    4804453           1     8    1.00      3.00 0.00 50.00   233.00
# 24564    4804454           1     1    1.00      2.00 1.00 27.00   387.00
# 24565    4804454           1     2    1.00      2.00 0.00 24.00   387.00
# 24566    4804455           1     1    1.00      3.00 0.00 36.00   341.00
#
#        maxeduclevel  y_salary_m_hu     y_total_m  p6585s1  p6585s2  p6585s3  \
# 1              6.00        6740.74    1620833.25        1        0        1
# 6              7.00        5833.33   1378973.375        0        1        0
# 9              4.00        3073.82        883357        0        1        0
# 11             3.00        4083.33         7e+05        0        0        0
# 16             7.00        8263.89   1941500.125        0        0        1
# ...             ...            ...           ...      ...      ...      ...
# 24560          7.00        5045.83       1088000        0        1        0
# 24562          6.00        4310.30   1146544.375        0        1        0
# 24564          6.00        3797.70   916119.6875        0        1        1
# 24565          6.00        3000.00  1003666.6875        0        0        1
# 24566          7.00       24500.00       6675000        0        0        0
#
#        p6585s4
# 1            0
# 6            0
# 9            0
# 11           0
# 16           0
# ...        ...
# 24560        0
# 24562        0
# 24564        0
# 24565        0
# 24566        0
#
# [9844 rows x 15 columns]

# %%
#  Missing
missing_values = df_18.isnull().sum()
missing_values
# Out:
# directorio       0
# secuencia_p      0
# orden            0
# formal           0
# estrato1         0
# sex              0
# age              0
# fweight          0
# maxeduclevel     0
# y_salary_m_hu    0
# y_total_m        0
# p6585s1          0
# p6585s2          0
# p6585s3          0
# p6585s4          0
# dtype: int64

# %%
# 4. Guardamos el dataframe en un archivo CSV
df_18.to_csv(DATASET_CLEAN, index=False)
